# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# %cd ./gdrive/MyDrive/Colab_Notebooks/
# !pwd
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/MyDrive/Colab_Notebooks
# /content/gdrive/MyDrive/Colab_Notebooks

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Colab_Notebooks/.git/

# %%
# !git remote remove origin

# %%
# !git remote add origin https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git

# %%
# !git remote -v
# Out:
# origin	https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git (fetch)
# origin	https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git (push)

# %%
# !git config --global user.email "ankurroy2356@gmail.com"

# %%
# !git config user.name "ankur2392roy"

# %%
# !git config credential.username "ankur2392roy"

# %%
# !git add .

# %%
# !git commit -m 'Third commit'
# Out:
# [master 066e92b] Third commit
#  2 files changed, 1 insertion(+), 181 deletions(-)
#  delete mode 100644 ML_project2.ipynb
#  rewrite git.ipynb (78%)

# %%
# !git pull origin master
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 2 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (2/2), done.
# From https://github.com/ankur2392roy/ML_proj2
#  * branch            master     -> FETCH_HEAD
#  * [new branch]      master     -> origin/master
# <e/MyDrive/Colab_Notebooks/.git/MERGE_MSG" 7L, 293C▽  [>cMerge branch 'master' of https://github.com/ankur2392roy/ML_proj2
#
# # Please enter a commit message to explain why this merge is necessary,
# # especially if it merges an updated upstream into a topic branch.
# #
# # Lines starting with '#' will be ignored, and an empty message aborts
# # the commit.
# ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               1,1All

# %%
# !git push -u origin master
