# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# %cd ./gdrive/MyDrive/Colab_Notebooks/
# !pwd
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/MyDrive/Colab_Notebooks
# /content/gdrive/MyDrive/Colab_Notebooks

# %%
# !git init
user='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'
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Colab_Notebooks/.git/

# %%
# !git remote remove origin

# %%
# !git remote add origin https://ankur2392roy:user@github.com/ankur2392roy/ML_proj2.git

# %%
# !git remote -v
# Out:
# origin	https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git (fetch)
# origin	https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git (push)

# %%
# !git config --global user.email "ankurroy2356@gmail.com"

# %%
# !git config user.name "ankur2392roy"

# %%
# !git config credential.username "ankur2392roy"

# %%
# !git add *

# %%
# !git commit -m 'Second commit'
# Out:
# [master d77c3aa] Second commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git.ipynb (81%)

# %%
#!git pull origin master

# %%
# !git push origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.03 KiB | 264.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/ankur2392roy/ML_proj2.git
#    41b9808..d77c3aa  master -> master
