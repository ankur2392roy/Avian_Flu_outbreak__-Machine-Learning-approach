# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# %cd ./gdrive/MyDrive/Colab_Notebooks/
# !pwd
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/MyDrive/Colab_Notebooks
# /content/gdrive/MyDrive/Colab_Notebooks

# %%
# !git init
username='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'
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Colab_Notebooks/.git/

# %%
# !git remote remove origin

# %%
# !git remote add origin https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git

# %%
# !git remote -v
# Out:
# origin	https://ankur2392roy:username@github.com/ankur2392roy/ML_proj2.git (fetch)
# origin	https://ankur2392roy:username@github.com/ankur2392roy/ML_proj2.git (push)

# %%
# !git config --global user.email "ankurroy2356@gmail.com"

# %%
# !git config user.name "ankur2392roy"

# %%
# !git config credential.username "ankur2392roy"

# %%
# !git add *

# %%
# !git commit -m 'Second commit'
# Out:
# On branch master
# Changes not staged for commit:
# 	deleted:    ML_project2.ipynb
#
# no changes added to commit

# %%
#!git pull origin master

# %%
# !git push origin master
# Out:
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/en/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://ankur2392roy:username@github.com/ankur2392roy/ML_proj2.git/'
