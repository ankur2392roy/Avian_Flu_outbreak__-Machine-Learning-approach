# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# %cd ./gdrive/MyDrive/Colab_Notebooks/
# !pwd
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# [Errno 2] No such file or directory: './gdrive/MyDrive/Colab_Notebooks/'
# /content/gdrive/MyDrive/Colab_Notebooks
# /content/gdrive/My Drive/Colab_Notebooks

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/Colab_Notebooks/.git/

# %%
# !git remote remove origin

# %%
# !git remote add origin https://ankur2392roy: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@github.com/ankur2392roy/Ml_proj2.git

# %%
# !git remote -v
# Out:
# origin	https://ankur2392roy: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@github.com/ankur2392roy/Ml_proj2.git (fetch)
# origin	https://ankur2392roy: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@github.com/ankur2392roy/Ml_proj2.git (push)

# %%
# !git config --global user.email "ankurroy2356@gmail.com"

# %%
# !git config user.name "ankur2392roy"

# %%
git config credential.username "ankur2392ro"

# %%
# !git add .

# %%
# !git commit -m 'First commit'
# Out:
# [master 2ea87af] First commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git.ipynb (70%)

# %%
# !git push origin master
# Out:
# remote: Permission to ankur2392roy/Ml_proj2.git denied to ankur2392roy.
# fatal: unable to access 'https://ankur2392roy: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@github.com/ankur2392roy/Ml_proj2.git/': The requested URL returned error: 403
