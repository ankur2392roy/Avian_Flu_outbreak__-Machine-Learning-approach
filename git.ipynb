# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# %cd ./gdrive/MyDrive/Colab_Notebooks/
# !pwd
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/MyDrive/Colab_Notebooks
# /content/gdrive/MyDrive/Colab_Notebooks

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Colab_Notebooks/.git/

# %%
# !git remote remove origin

# %%
# !git remote add origin https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git

# %%
# !git remote -v
# Out:
# origin	https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git (fetch)
# origin	https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git (push)

# %%
# !git config --global user.email "ankurroy2356@gmail.com"

# %%
# !git config user.name "ankur2392roy"

# %%
# !git config credential.username "ankur2392roy"

# %%
# !git add *

# %%
# !git commit -m 'Second commit'
# Out:
# [master 432ead8] Second commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git.ipynb (87%)

# %%
#!git pull origin master

# %%
# !git push origin master
# Out:
# Counting objects: 9, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 2.58 KiB | 439.00 KiB/s, done.
# Total 9 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 2 local objects.
# To https://github.com/ankur2392roy/ML_proj2.git
#    d77c3aa..432ead8  master -> master
