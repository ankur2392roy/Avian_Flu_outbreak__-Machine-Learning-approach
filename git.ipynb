# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# %cd ./gdrive/MyDrive/Colab_Notebooks/
# !pwd
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/MyDrive/Colab_Notebooks
# /content/gdrive/MyDrive/Colab_Notebooks

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Colab_Notebooks/.git/

# %%
# !git remote remove origin

# %%
# !git remote add origin https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git

# %%
# !git remote -v
# Out:
# origin	https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git (fetch)
# origin	https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git (push)

# %%
# !git config --global user.email "ankurroy2356@gmail.com"

# %%
# !git config user.name "ankur2392roy"

# %%
# !git config credential.username "ankur2392roy"

# %%
# !git add .

# %%
# !git commit -m 'Second commit'
# Out:
# [master 6ce7431] Second commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git.ipynb (94%)

# %%
# !git pull origin master
# Out:
# From https://github.com/ankur2392roy/ML_proj2
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
# !git push https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git/'
