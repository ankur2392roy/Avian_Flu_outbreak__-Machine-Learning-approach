# %%
from google.colab import drive 
drive.mount('/content/gdrive/')
# %cd ./gdrive/MyDrive/Colab_Notebooks/
# !pwd
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/MyDrive/Colab_Notebooks
# /content/gdrive/MyDrive/Colab_Notebooks

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Colab_Notebooks/.git/

# %%
# !git remote remove origin

# %%
# !git remote add origin https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git

# %%
# !git remote -v
# Out:
# origin	https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git (fetch)
# origin	https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git (push)

# %%
# !git config --global user.email "ankurroy2356@gmail.com"

# %%
# !git config user.name "ankur2392roy"

# %%
# !git config credential.username "ankur2392roy"

# %%
# !git add *

# %%
# !git commit -m 'Second commit'
# Out:
# [master de3548f] Second commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite git.ipynb (80%)

# %%
#!git pull origin master

# %%
# !git push origin master
# Out:
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://ankur2392roy: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@github.com/ankur2392roy/ML_proj2.git/'
